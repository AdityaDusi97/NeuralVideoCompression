# %%
import torch 
import torch.nn as nn
import torchvision
import pdb

# %%
data_path = "../data/vid1"

# %%
def FrameLoader(data_path):
    #data_path = 'data/train/'
    dataloader = torchvision.datasets.ImageFolder(
        root=data_path,
        transform=torchvision.transforms.ToTensor()
    )
    dataset = torch.utils.data.DataLoader(
        dataloader,
        batch_size=4,
        num_workers=0,
        shuffle=False
    )
    return dataset

# %%
data = FrameLoader(data_path)

# %%
for idx, (d,_) in enumerate(data):
    pdb.set_trace()
# Out:
# > <ipython-input-24-aa9501a0e66d>(1)<module>()
# -> for idx, (d,_) in enumerate(data):
# (Pdb) n
# > <ipython-input-24-aa9501a0e66d>(2)<module>()
# -> pdb.set_trace()
# (Pdb) idx
# 1
# (Pdb) d
# *** Newest frame
# (Pdb) print(d)
# tensor([[[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0039],
#           [0.0000, 0.0000, 0.0039,  ..., 1.0000, 0.0000, 1.0000],
#           ...,
#           [0.0039, 0.0000, 0.0039,  ..., 0.9961, 1.0000, 0.0000],
#           [0.0000, 0.0000, 0.0039,  ..., 0.9961, 0.9961, 0.9961],
#           [1.0000, 0.0078, 0.0078,  ..., 0.9961, 1.0000, 0.9961]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0039],
#           [0.0039, 0.0039, 0.0078,  ..., 1.0000, 0.0000, 1.0000],
#           ...,
#           [0.0039, 0.0000, 0.9961,  ..., 1.0000, 0.0000, 0.0039],
# ...

# %%
len(data)
# Out:
# 20
